# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import pickle
import operator
from pylab import *
from sklearn.decomposition import PCA

# %%
import sys
sys.path.append("/opt/conda/lib/python3.7/site-packages") ##添加xbg路径
import woe.feature_process as fp
import woe.eval as eval

# %%
from time import time
import scipy.stats as stats
import gc

from bayes_opt import BayesianOptimization

from sklearn.model_selection import cross_val_score, StratifiedKFold, StratifiedShuffleSplit, train_test_split, RandomizedSearchCV, PredefinedSplit
from sklearn.metrics import log_loss, matthews_corrcoef, roc_auc_score
from sklearn.preprocessing import MinMaxScaler
import contextlib

# %%
from sklearn.metrics import accuracy_score
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import roc_curve, RocCurveDisplay,auc
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay

# %%
name = []
for i in range(0,40):
    if i < 10:
        string = "data_721/part-0000"+str(i)+"-0225fca5-6f5a-427f-9f52-9c6180d510e3-c000.csv"
    else:
        string = "data_721/part-000"+str(i)+"-0225fca5-6f5a-427f-9f52-9c6180d510e3-c000.csv"
    name.append(string)

# %%
df = pd.concat(
    map(pd.read_csv, name), ignore_index=True)

# %%
df['date_wid'] = pd.to_datetime(df['date_wid'])

# %%
df.rename(columns={"flag": "target"}, inplace=True)

# %%
train=df[(df['class']=="test")&(df['date_wid']>='2023-01-01')&(df['date_wid']<'2023-04-01')]

# %%
dt_train = df[(df['class']=="test")&(df['date_wid']>='2023-04-01')&(df['date_wid']<'2023-05-01')]

# %%
train=train.drop(['account_code','social_credit_num','created','date_wid','class'], axis=1)

# %%
train['lastbuy_date_diff'] = train['lastbuy_date_diff'].fillna(9999)
train = train.fillna(0)

# %%
train[['unit_level','act_category','act_alias','ent_level','ent_category']]=train[['unit_level','act_category','act_alias','ent_level','ent_category']].astype(str)

# %%
train2 = train.copy()

# %%
data_woe = train2 #用于存储所有数据的woe值
civ_list = []
n_positive = sum(train2['target'])
n_negtive = len(train2) - n_positive
for column in list(train2.columns[2:]):
    if train2[column].dtypes == 'object':
        civ = fp.proc_woe_discrete(train2, column, n_positive, n_negtive, 0.05*len(train2), alpha=0.05)
    else:  
        civ = fp.proc_woe_continuous(train2, column, n_positive, n_negtive, 0.05*len(train2), alpha=0.05)
    civ_list.append(civ)
    data_woe[column] = fp.woe_trans(train2[column], civ)

civ_df = eval.eval_feature_detail(civ_list,'train_output.csv')
# Out:
# -------process continuous variable:lastbuy_date_diff--------
# -------process continuous variable:thisyear_newsales--------
# -------process continuous variable:lastyear_newsales--------
# -------process continuous variable:thisyear_newbuycnt-------
# -------process continuous variable:lastyear_newbuycnt-------
# ------------process continuous variable:cir_day-------------
# ----process continuous variable:register_count_pv_15_pv-----
# ----process continuous variable:register_count_pv_30_pv-----
# ----process continuous variable:register_count_pv_60_pv-----
# ----process continuous variable:register_count_pv_120_pv----
# ----process continuous variable:register_count_pv_15_uv-----
# ----process continuous variable:register_count_pv_30_uv-----
# ----process continuous variable:register_count_pv_60_uv-----
# ----process continuous variable:register_count_pv_120_uv----
# -----process continuous variable:signup_count_pv_15_pv------
# -----process continuous variable:signup_count_pv_30_pv------
# -----process continuous variable:signup_count_pv_60_pv------
# -----process continuous variable:signup_count_pv_120_pv-----
# -----process continuous variable:signup_count_pv_15_uv------
# -----process continuous variable:signup_count_pv_30_uv------
# -----process continuous variable:signup_count_pv_60_uv------
# -----process continuous variable:signup_count_pv_120_uv-----
# ------process continuous variable:register_count_15_pv------
# ------process continuous variable:register_count_30_pv------
# ------process continuous variable:register_count_60_pv------
# -----process continuous variable:register_count_120_pv------
# ------process continuous variable:register_count_15_uv------
# ------process continuous variable:register_count_30_uv------
# ------process continuous variable:register_count_60_uv------
# -----process continuous variable:register_count_120_uv------
# -------process continuous variable:signup_count_15_pv-------
# -------process continuous variable:signup_count_30_pv-------
# -------process continuous variable:signup_count_60_pv-------
# ------process continuous variable:signup_count_120_pv-------
# -------process continuous variable:signup_count_15_uv-------
# -------process continuous variable:signup_count_30_uv-------
# -------process continuous variable:signup_count_60_uv-------
# ------process continuous variable:signup_count_120_uv-------
# ------process continuous variable:click_count_pv_15_pv------
# ------process continuous variable:click_count_pv_30_pv------
# ------process continuous variable:click_count_pv_60_pv------
# -----process continuous variable:click_count_pv_120_pv------
# ------process continuous variable:click_count_pv_15_uv------
# ------process continuous variable:click_count_pv_30_uv------
# ------process continuous variable:click_count_pv_60_uv------
# -----process continuous variable:click_count_pv_120_uv------
# ------process continuous variable:share_count_pv_15_pv------
# ------process continuous variable:share_count_pv_30_pv------
# ------process continuous variable:share_count_pv_60_pv------
# -----process continuous variable:share_count_pv_120_pv------
# ------process continuous variable:share_count_pv_15_uv------
# ------process continuous variable:share_count_pv_30_uv------
# ------process continuous variable:share_count_pv_60_uv------
# -----process continuous variable:share_count_pv_120_uv------
# ----process continuous variable:favorite_count_pv_15_pv-----
# ----process continuous variable:favorite_count_pv_30_pv-----
# ----process continuous variable:favorite_count_pv_60_pv-----
# ----process continuous variable:favorite_count_pv_120_pv----
# ----process continuous variable:favorite_count_pv_15_uv-----
# ----process continuous variable:favorite_count_pv_30_uv-----
# ----process continuous variable:favorite_count_pv_60_uv-----
# ----process continuous variable:favorite_count_pv_120_uv----
# ----process continuous variable:download_count_pv_15_pv-----
# ----process continuous variable:download_count_pv_30_pv-----
# ----process continuous variable:download_count_pv_60_pv-----
# ----process continuous variable:download_count_pv_120_pv----
# ----process continuous variable:download_count_pv_15_uv-----
# ----process continuous variable:download_count_pv_30_uv-----
# ----process continuous variable:download_count_pv_60_uv-----
# ----process continuous variable:download_count_pv_120_uv----
# ------process continuous variable:email_count_pv_15_pv------
# ------process continuous variable:email_count_pv_30_pv------
# ------process continuous variable:email_count_pv_60_pv------
# -----process continuous variable:email_count_pv_120_pv------
# ------process continuous variable:email_count_pv_15_uv------
# ------process continuous variable:email_count_pv_30_uv------
# ------process continuous variable:email_count_pv_60_uv------
# -----process continuous variable:email_count_pv_120_uv------
# -----process continuous variable:replay_count_pv_15_pv------
# -----process continuous variable:replay_count_pv_30_pv------
# -----process continuous variable:replay_count_pv_60_pv------
# -----process continuous variable:replay_count_pv_120_pv-----
# -----process continuous variable:replay_count_pv_15_uv------
# -----process continuous variable:replay_count_pv_30_uv------
# -----process continuous variable:replay_count_pv_60_uv------
# -----process continuous variable:replay_count_pv_120_uv-----
# ---process continuous variable:explicit_demand_flag_15_pv---
# ---process continuous variable:explicit_demand_flag_30_pv---
# ---process continuous variable:explicit_demand_flag_60_pv---
# --process continuous variable:explicit_demand_flag_120_pv---
# ---process continuous variable:explicit_demand_flag_15_uv---
# ---process continuous variable:explicit_demand_flag_30_uv---
# ---process continuous variable:explicit_demand_flag_60_uv---
# --process continuous variable:explicit_demand_flag_120_uv---
# -----process continuous variable:intent_buy_flag_15_pv------
# -----process continuous variable:intent_buy_flag_30_pv------
# -----process continuous variable:intent_buy_flag_60_pv------
# -----process continuous variable:intent_buy_flag_120_pv-----
# -----process continuous variable:intent_buy_flag_15_uv------
# -----process continuous variable:intent_buy_flag_30_uv------
# -----process continuous variable:intent_buy_flag_60_uv------
# -----process continuous variable:intent_buy_flag_120_uv-----
# ---process continuous variable:implicit_demand_flag_15_pv---
# ---process continuous variable:implicit_demand_flag_30_pv---
# ---process continuous variable:implicit_demand_flag_60_pv---
# --process continuous variable:implicit_demand_flag_120_pv---
# ---process continuous variable:implicit_demand_flag_15_uv---
# ---process continuous variable:implicit_demand_flag_30_uv---
# ---process continuous variable:implicit_demand_flag_60_uv---
# --process continuous variable:implicit_demand_flag_120_uv---
# --------process continuous variable:watch_time_15_pv--------
# --------process continuous variable:watch_time_30_pv--------
# --------process continuous variable:watch_time_60_pv--------
# -------process continuous variable:watch_time_120_pv--------
# --------process continuous variable:watch_time_15_uv--------
# --------process continuous variable:watch_time_30_uv--------
# --------process continuous variable:watch_time_60_uv--------
# -------process continuous variable:watch_time_120_uv--------
# --------process continuous variable:live_time_15_pv---------
# --------process continuous variable:live_time_30_pv---------
# --------process continuous variable:live_time_60_pv---------
# --------process continuous variable:live_time_120_pv--------
# --------process continuous variable:live_time_15_uv---------
# --------process continuous variable:live_time_30_uv---------
# --------process continuous variable:live_time_60_uv---------
# --------process continuous variable:live_time_120_uv--------
# ---------process continuous variable:vod_time_15_pv---------
# ---------process continuous variable:vod_time_30_pv---------
# ---------process continuous variable:vod_time_60_pv---------
# --------process continuous variable:vod_time_120_pv---------
# ---------process continuous variable:vod_time_15_uv---------
# ---------process continuous variable:vod_time_30_uv---------
# ---------process continuous variable:vod_time_60_uv---------
# --------process continuous variable:vod_time_120_uv---------
# -------process continuous variable:online_time_15_pv--------
# -------process continuous variable:online_time_30_pv--------
# -------process continuous variable:online_time_60_pv--------
# -------process continuous variable:online_time_120_pv-------
# -------process continuous variable:online_time_15_uv--------
# -------process continuous variable:online_time_30_uv--------
# -------process continuous variable:online_time_60_uv--------
# -------process continuous variable:online_time_120_uv-------
# ---------process continuous variable:renew_lock_cnt---------
# ------process continuous variable:min_renew_date_diff-------
# --------------process discrete variable:branch--------------
# /opt/conda/lib/python3.7/site-packages/woe/feature_process.py:414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[var] = cpvar
# ------------process discrete variable:management------------
# ---------process continuous variable:regist_capital---------
# ------------process discrete variable:unit_level------------
# -----------process discrete variable:act_category-----------
# ------------process discrete variable:act_alias-------------
# -----------process discrete variable:ent_category-----------
# ------------process discrete variable:ent_level-------------
# -------------process discrete variable:industry-------------
# --------process continuous variable:jkzh_work_15_pv---------
# --------process continuous variable:jkzh_work_30_pv---------
# --------process continuous variable:jkzh_work_60_pv---------
# --------process continuous variable:jkzh_work_120_pv--------
# --------process continuous variable:jkzh_work_15_uv---------
# --------process continuous variable:jkzh_work_30_uv---------
# --------process continuous variable:jkzh_work_60_uv---------
# --------process continuous variable:jkzh_work_120_uv--------
# --------process continuous variable:gjg_trial_15_pv---------
# --------process continuous variable:gjg_trial_30_pv---------
# --------process continuous variable:gjg_trial_60_pv---------
# --------process continuous variable:gjg_trial_120_pv--------
# --------process continuous variable:gjg_trial_15_uv---------
# --------process continuous variable:gjg_trial_30_uv---------
# --------process continuous variable:gjg_trial_60_uv---------
# --------process continuous variable:gjg_trial_120_uv--------
# --------process continuous variable:gjg_curbuy_15_pv--------
# --------process continuous variable:gjg_curbuy_30_pv--------
# --------process continuous variable:gjg_curbuy_60_pv--------
# -------process continuous variable:gjg_curbuy_120_pv--------
# --------process continuous variable:gjg_curbuy_15_uv--------
# --------process continuous variable:gjg_curbuy_30_uv--------
# --------process continuous variable:gjg_curbuy_60_uv--------
# -------process continuous variable:gjg_curbuy_120_uv--------
# -------process continuous variable:jkzh_worknew_15_pv-------
# -------process continuous variable:jkzh_worknew_30_pv-------
# -------process continuous variable:jkzh_worknew_60_pv-------
# ------process continuous variable:jkzh_worknew_120_pv-------
# -------process continuous variable:jkzh_worknew_15_uv-------
# -------process continuous variable:jkzh_worknew_30_uv-------
# -------process continuous variable:jkzh_worknew_60_uv-------
# ------process continuous variable:jkzh_worknew_120_uv-------
# ------process continuous variable:jkzh_pointmod_15_pv-------
# ------process continuous variable:jkzh_pointmod_30_pv-------
# ------process continuous variable:jkzh_pointmod_60_pv-------
# ------process continuous variable:jkzh_pointmod_120_pv------
# ------process continuous variable:jkzh_pointmod_15_uv-------
# ------process continuous variable:jkzh_pointmod_30_uv-------
# ------process continuous variable:jkzh_pointmod_60_uv-------
# ------process continuous variable:jkzh_pointmod_120_uv------
# --------process continuous variable:jkzh_trial_15_pv--------
# --------process continuous variable:jkzh_trial_30_pv--------
# --------process continuous variable:jkzh_trial_60_pv--------
# -------process continuous variable:jkzh_trial_120_pv--------
# --------process continuous variable:jkzh_trial_15_uv--------
# --------process continuous variable:jkzh_trial_30_uv--------
# --------process continuous variable:jkzh_trial_60_uv--------
# -------process continuous variable:jkzh_trial_120_uv--------
# ------process continuous variable:jkzh_pointbuy_15_pv-------
# ------process continuous variable:jkzh_pointbuy_30_pv-------
# ------process continuous variable:jkzh_pointbuy_60_pv-------
# ------process continuous variable:jkzh_pointbuy_120_pv------
# ------process continuous variable:jkzh_pointbuy_15_uv-------
# ------process continuous variable:jkzh_pointbuy_30_uv-------
# ------process continuous variable:jkzh_pointbuy_60_uv-------
# ------process continuous variable:jkzh_pointbuy_120_uv------
# ------process continuous variable:jkzh_endtrial_15_pv-------
# ------process continuous variable:jkzh_endtrial_30_pv-------
# ------process continuous variable:jkzh_endtrial_60_pv-------
# ------process continuous variable:jkzh_endtrial_120_pv------
# ------process continuous variable:jkzh_endtrial_15_uv-------
# ------process continuous variable:jkzh_endtrial_30_uv-------
# ------process continuous variable:jkzh_endtrial_60_uv-------
# ------process continuous variable:jkzh_endtrial_120_uv------
# ------process continuous variable:sgd_prometanum_15_pv------
# ------process continuous variable:sgd_prometanum_30_pv------
# ------process continuous variable:sgd_prometanum_60_pv------
# -----process continuous variable:sgd_prometanum_120_pv------
# ------process continuous variable:sgd_prometanum_15_uv------
# ------process continuous variable:sgd_prometanum_30_uv------
# ------process continuous variable:sgd_prometanum_60_uv------
# -----process continuous variable:sgd_prometanum_120_uv------
# -----process continuous variable:sgd_prometapoint_15_pv-----
# -----process continuous variable:sgd_prometapoint_30_pv-----
# -----process continuous variable:sgd_prometapoint_60_pv-----
# ----process continuous variable:sgd_prometapoint_120_pv-----
# -----process continuous variable:sgd_prometapoint_15_uv-----
# -----process continuous variable:sgd_prometapoint_30_uv-----
# -----process continuous variable:sgd_prometapoint_60_uv-----
# ----process continuous variable:sgd_prometapoint_120_uv-----
# --------process continuous variable:sgd_pro_jd_15_pv--------
# --------process continuous variable:sgd_pro_jd_30_pv--------
# --------process continuous variable:sgd_pro_jd_60_pv--------
# -------process continuous variable:sgd_pro_jd_120_pv--------
# --------process continuous variable:sgd_pro_jd_15_uv--------
# --------process continuous variable:sgd_pro_jd_30_uv--------
# --------process continuous variable:sgd_pro_jd_60_uv--------
# -------process continuous variable:sgd_pro_jd_120_uv--------
# --------process continuous variable:sgd_pro_dx_15_pv--------
# --------process continuous variable:sgd_pro_dx_30_pv--------
# --------process continuous variable:sgd_pro_dx_60_pv--------
# -------process continuous variable:sgd_pro_dx_120_pv--------
# --------process continuous variable:sgd_pro_dx_15_uv--------
# --------process continuous variable:sgd_pro_dx_30_uv--------
# --------process continuous variable:sgd_pro_dx_60_uv--------
# -------process continuous variable:sgd_pro_dx_120_uv--------
# ----------process continuous variable:sgd_jc_15_pv----------
# ----------process continuous variable:sgd_jc_30_pv----------
# ----------process continuous variable:sgd_jc_60_pv----------
# ---------process continuous variable:sgd_jc_120_pv----------
# ----------process continuous variable:sgd_jc_15_uv----------
# ----------process continuous variable:sgd_jc_30_uv----------
# ----------process continuous variable:sgd_jc_60_uv----------
# ---------process continuous variable:sgd_jc_120_uv----------
# -------process continuous variable:gjg_pointmod_15_pv-------
# -------process continuous variable:gjg_pointmod_30_pv-------
# -------process continuous variable:gjg_pointmod_60_pv-------
# ------process continuous variable:gjg_pointmod_120_pv-------
# -------process continuous variable:gjg_pointmod_15_uv-------
# -------process continuous variable:gjg_pointmod_30_uv-------
# -------process continuous variable:gjg_pointmod_60_uv-------
# ------process continuous variable:gjg_pointmod_120_uv-------
# --------process continuous variable:gjg_start_15_pv---------
# --------process continuous variable:gjg_start_30_pv---------
# --------process continuous variable:gjg_start_60_pv---------
# --------process continuous variable:gjg_start_120_pv--------
# --------process continuous variable:gjg_start_15_uv---------
# --------process continuous variable:gjg_start_30_uv---------
# --------process continuous variable:gjg_start_60_uv---------
# --------process continuous variable:gjg_start_120_uv--------
# --------process continuous variable:sgd_point_15_pv---------
# --------process continuous variable:sgd_point_30_pv---------
# --------process continuous variable:sgd_point_60_pv---------
# --------process continuous variable:sgd_point_120_pv--------
# --------process continuous variable:sgd_point_15_uv---------
# --------process continuous variable:sgd_point_30_uv---------
# --------process continuous variable:sgd_point_60_uv---------
# --------process continuous variable:sgd_point_120_uv--------
# -------process continuous variable:sgd_pointmod_15_pv-------
# -------process continuous variable:sgd_pointmod_30_pv-------
# -------process continuous variable:sgd_pointmod_60_pv-------
# ------process continuous variable:sgd_pointmod_120_pv-------
# -------process continuous variable:sgd_pointmod_15_uv-------
# -------process continuous variable:sgd_pointmod_30_uv-------
# -------process continuous variable:sgd_pointmod_60_uv-------
# ------process continuous variable:sgd_pointmod_120_uv-------
# --------process continuous variable:sgd_trial_15_pv---------
# --------process continuous variable:sgd_trial_30_pv---------
# --------process continuous variable:sgd_trial_60_pv---------
# --------process continuous variable:sgd_trial_120_pv--------
# --------process continuous variable:sgd_trial_15_uv---------
# --------process continuous variable:sgd_trial_30_uv---------
# --------process continuous variable:sgd_trial_60_uv---------
# --------process continuous variable:sgd_trial_120_uv--------
# -------process continuous variable:sgd_pointbuy_15_pv-------
# -------process continuous variable:sgd_pointbuy_30_pv-------
# -------process continuous variable:sgd_pointbuy_60_pv-------
# ------process continuous variable:sgd_pointbuy_120_pv-------
# -------process continuous variable:sgd_pointbuy_15_uv-------
# -------process continuous variable:sgd_pointbuy_30_uv-------
# -------process continuous variable:sgd_pointbuy_60_uv-------
# ------process continuous variable:sgd_pointbuy_120_uv-------
# -------process continuous variable:sgd_endtrial_15_pv-------
# -------process continuous variable:sgd_endtrial_30_pv-------
# -------process continuous variable:sgd_endtrial_60_pv-------
# ------process continuous variable:sgd_endtrial_120_pv-------
# -------process continuous variable:sgd_endtrial_15_uv-------
# -------process continuous variable:sgd_endtrial_30_uv-------
# -------process continuous variable:sgd_endtrial_60_uv-------
# ------process continuous variable:sgd_endtrial_120_uv-------
# ---------process continuous variable:zps_work_15_pv---------
# ---------process continuous variable:zps_work_30_pv---------
# ---------process continuous variable:zps_work_60_pv---------
# --------process continuous variable:zps_work_120_pv---------
# ---------process continuous variable:zps_work_15_uv---------
# ---------process continuous variable:zps_work_30_uv---------
# ---------process continuous variable:zps_work_60_uv---------
# --------process continuous variable:zps_work_120_uv---------
# -------process continuous variable:zps_pointmod_15_pv-------
# -------process continuous variable:zps_pointmod_30_pv-------
# -------process continuous variable:zps_pointmod_60_pv-------
# ------process continuous variable:zps_pointmod_120_pv-------
# -------process continuous variable:zps_pointmod_15_uv-------
# -------process continuous variable:zps_pointmod_30_uv-------
# -------process continuous variable:zps_pointmod_60_uv-------
# ------process continuous variable:zps_pointmod_120_uv-------
# --------process continuous variable:zps_trial_15_pv---------
# --------process continuous variable:zps_trial_30_pv---------
# --------process continuous variable:zps_trial_60_pv---------
# --------process continuous variable:zps_trial_120_pv--------
# --------process continuous variable:zps_trial_15_uv---------
# --------process continuous variable:zps_trial_30_uv---------
# --------process continuous variable:zps_trial_60_uv---------
# --------process continuous variable:zps_trial_120_uv--------
# -------process continuous variable:zps_pointbuy_15_pv-------
# -------process continuous variable:zps_pointbuy_30_pv-------
# -------process continuous variable:zps_pointbuy_60_pv-------
# ------process continuous variable:zps_pointbuy_120_pv-------
# -------process continuous variable:zps_pointbuy_15_uv-------
# -------process continuous variable:zps_pointbuy_30_uv-------
# -------process continuous variable:zps_pointbuy_60_uv-------
# ------process continuous variable:zps_pointbuy_120_uv-------
# -------process continuous variable:zps_endtrial_15_pv-------
# -------process continuous variable:zps_endtrial_30_pv-------
# -------process continuous variable:zps_endtrial_60_pv-------
# ------process continuous variable:zps_endtrial_120_pv-------
# -------process continuous variable:zps_endtrial_15_uv-------
# -------process continuous variable:zps_endtrial_30_uv-------
# -------process continuous variable:zps_endtrial_60_uv-------
# ------process continuous variable:zps_endtrial_120_uv-------
# ----------process continuous variable:lock_cnt_gtj----------
# ------------process continuous variable:jkzh_ab-------------
# -------------process continuous variable:sgd_ab-------------
# -------------process continuous variable:zps_ab-------------
# ------------process continuous variable:jkzh_gjg------------
# lastbuy_date_diff
# thisyear_newsales
# lastyear_newsales
# thisyear_newbuycnt
# lastyear_newbuycnt
# cir_day
# register_count_pv_15_pv
# register_count_pv_30_pv
# register_count_pv_60_pv
# register_count_pv_120_pv
# register_count_pv_15_uv
# register_count_pv_30_uv
# register_count_pv_60_uv
# register_count_pv_120_uv
# signup_count_pv_15_pv
# signup_count_pv_30_pv
# signup_count_pv_60_pv
# signup_count_pv_120_pv
# signup_count_pv_15_uv
# signup_count_pv_30_uv
# signup_count_pv_60_uv
# signup_count_pv_120_uv
# register_count_15_pv
# register_count_30_pv
# register_count_60_pv
# register_count_120_pv
# register_count_15_uv
# register_count_30_uv
# register_count_60_uv
# register_count_120_uv
# signup_count_15_pv
# signup_count_30_pv
# signup_count_60_pv
# signup_count_120_pv
# signup_count_15_uv
# signup_count_30_uv
# signup_count_60_uv
# signup_count_120_uv
# click_count_pv_15_pv
# click_count_pv_30_pv
# click_count_pv_60_pv
# click_count_pv_120_pv
# click_count_pv_15_uv
# click_count_pv_30_uv
# click_count_pv_60_uv
# click_count_pv_120_uv
# share_count_pv_15_pv
# share_count_pv_30_pv
# share_count_pv_60_pv
# share_count_pv_120_pv
# share_count_pv_15_uv
# share_count_pv_30_uv
# share_count_pv_60_uv
# share_count_pv_120_uv
# favorite_count_pv_15_pv
# favorite_count_pv_30_pv
# favorite_count_pv_60_pv
# favorite_count_pv_120_pv
# favorite_count_pv_15_uv
# favorite_count_pv_30_uv
# favorite_count_pv_60_uv
# favorite_count_pv_120_uv
# download_count_pv_15_pv
# download_count_pv_30_pv
# download_count_pv_60_pv
# download_count_pv_120_pv
# download_count_pv_15_uv
# download_count_pv_30_uv
# download_count_pv_60_uv
# download_count_pv_120_uv
# email_count_pv_15_pv
# email_count_pv_30_pv
# email_count_pv_60_pv
# email_count_pv_120_pv
# email_count_pv_15_uv
# email_count_pv_30_uv
# email_count_pv_60_uv
# email_count_pv_120_uv
# replay_count_pv_15_pv
# replay_count_pv_30_pv
# replay_count_pv_60_pv
# replay_count_pv_120_pv
# replay_count_pv_15_uv
# replay_count_pv_30_uv
# replay_count_pv_60_uv
# replay_count_pv_120_uv
# explicit_demand_flag_15_pv
# explicit_demand_flag_30_pv
# explicit_demand_flag_60_pv
# explicit_demand_flag_120_pv
# explicit_demand_flag_15_uv
# explicit_demand_flag_30_uv
# explicit_demand_flag_60_uv
# explicit_demand_flag_120_uv
# intent_buy_flag_15_pv
# intent_buy_flag_30_pv
# intent_buy_flag_60_pv
# intent_buy_flag_120_pv
# intent_buy_flag_15_uv
# intent_buy_flag_30_uv
# intent_buy_flag_60_uv
# intent_buy_flag_120_uv
# implicit_demand_flag_15_pv
# implicit_demand_flag_30_pv
# implicit_demand_flag_60_pv
# implicit_demand_flag_120_pv
# implicit_demand_flag_15_uv
# implicit_demand_flag_30_uv
# implicit_demand_flag_60_uv
# implicit_demand_flag_120_uv
# watch_time_15_pv
# watch_time_30_pv
# watch_time_60_pv
# watch_time_120_pv
# watch_time_15_uv
# watch_time_30_uv
# watch_time_60_uv
# watch_time_120_uv
# live_time_15_pv
# live_time_30_pv
# live_time_60_pv
# live_time_120_pv
# live_time_15_uv
# live_time_30_uv
# live_time_60_uv
# live_time_120_uv
# vod_time_15_pv
# vod_time_30_pv
# vod_time_60_pv
# vod_time_120_pv
# vod_time_15_uv
# vod_time_30_uv
# vod_time_60_uv
# vod_time_120_uv
# online_time_15_pv
# online_time_30_pv
# online_time_60_pv
# online_time_120_pv
# online_time_15_uv
# online_time_30_uv
# online_time_60_uv
# online_time_120_uv
# renew_lock_cnt
# min_renew_date_diff
# branch
# management
# regist_capital
# unit_level
# act_category
# act_alias
# ent_category
# ent_level
# industry
# jkzh_work_15_pv
# jkzh_work_30_pv
# jkzh_work_60_pv
# jkzh_work_120_pv
# jkzh_work_15_uv
# jkzh_work_30_uv
# jkzh_work_60_uv
# jkzh_work_120_uv
# gjg_trial_15_pv
# gjg_trial_30_pv
# gjg_trial_60_pv
# gjg_trial_120_pv
# gjg_trial_15_uv
# gjg_trial_30_uv
# gjg_trial_60_uv
# gjg_trial_120_uv
# gjg_curbuy_15_pv
# gjg_curbuy_30_pv
# gjg_curbuy_60_pv
# gjg_curbuy_120_pv
# gjg_curbuy_15_uv
# gjg_curbuy_30_uv
# gjg_curbuy_60_uv
# gjg_curbuy_120_uv
# jkzh_worknew_15_pv
# jkzh_worknew_30_pv
# jkzh_worknew_60_pv
# jkzh_worknew_120_pv
# jkzh_worknew_15_uv
# jkzh_worknew_30_uv
# jkzh_worknew_60_uv
# jkzh_worknew_120_uv
# jkzh_pointmod_15_pv
# jkzh_pointmod_30_pv
# jkzh_pointmod_60_pv
# jkzh_pointmod_120_pv
# jkzh_pointmod_15_uv
# jkzh_pointmod_30_uv
# jkzh_pointmod_60_uv
# jkzh_pointmod_120_uv
# jkzh_trial_15_pv
# jkzh_trial_30_pv
# jkzh_trial_60_pv
# jkzh_trial_120_pv
# jkzh_trial_15_uv
# jkzh_trial_30_uv
# jkzh_trial_60_uv
# jkzh_trial_120_uv
# jkzh_pointbuy_15_pv
# jkzh_pointbuy_30_pv
# jkzh_pointbuy_60_pv
# jkzh_pointbuy_120_pv
# jkzh_pointbuy_15_uv
# jkzh_pointbuy_30_uv
# jkzh_pointbuy_60_uv
# jkzh_pointbuy_120_uv
# jkzh_endtrial_15_pv
# jkzh_endtrial_30_pv
# jkzh_endtrial_60_pv
# jkzh_endtrial_120_pv
# jkzh_endtrial_15_uv
# jkzh_endtrial_30_uv
# jkzh_endtrial_60_uv
# jkzh_endtrial_120_uv
# sgd_prometanum_15_pv
# sgd_prometanum_30_pv
# sgd_prometanum_60_pv
# sgd_prometanum_120_pv
# sgd_prometanum_15_uv
# sgd_prometanum_30_uv
# sgd_prometanum_60_uv
# sgd_prometanum_120_uv
# sgd_prometapoint_15_pv
# sgd_prometapoint_30_pv
# sgd_prometapoint_60_pv
# sgd_prometapoint_120_pv
# sgd_prometapoint_15_uv
# sgd_prometapoint_30_uv
# sgd_prometapoint_60_uv
# sgd_prometapoint_120_uv
# sgd_pro_jd_15_pv
# sgd_pro_jd_30_pv
# sgd_pro_jd_60_pv
# sgd_pro_jd_120_pv
# sgd_pro_jd_15_uv
# sgd_pro_jd_30_uv
# sgd_pro_jd_60_uv
# sgd_pro_jd_120_uv
# sgd_pro_dx_15_pv
# sgd_pro_dx_30_pv
# sgd_pro_dx_60_pv
# sgd_pro_dx_120_pv
# sgd_pro_dx_15_uv
# sgd_pro_dx_30_uv
# sgd_pro_dx_60_uv
# sgd_pro_dx_120_uv
# sgd_jc_15_pv
# sgd_jc_30_pv
# sgd_jc_60_pv
# sgd_jc_120_pv
# sgd_jc_15_uv
# sgd_jc_30_uv
# sgd_jc_60_uv
# sgd_jc_120_uv
# gjg_pointmod_15_pv
# gjg_pointmod_30_pv
# gjg_pointmod_60_pv
# gjg_pointmod_120_pv
# gjg_pointmod_15_uv
# gjg_pointmod_30_uv
# gjg_pointmod_60_uv
# gjg_pointmod_120_uv
# gjg_start_15_pv
# gjg_start_30_pv
# gjg_start_60_pv
# gjg_start_120_pv
# gjg_start_15_uv
# gjg_start_30_uv
# gjg_start_60_uv
# gjg_start_120_uv
# sgd_point_15_pv
# sgd_point_30_pv
# sgd_point_60_pv
# sgd_point_120_pv
# sgd_point_15_uv
# sgd_point_30_uv
# sgd_point_60_uv
# sgd_point_120_uv
# sgd_pointmod_15_pv
# sgd_pointmod_30_pv
# sgd_pointmod_60_pv
# sgd_pointmod_120_pv
# sgd_pointmod_15_uv
# sgd_pointmod_30_uv
# sgd_pointmod_60_uv
# sgd_pointmod_120_uv
# sgd_trial_15_pv
# sgd_trial_30_pv
# sgd_trial_60_pv
# sgd_trial_120_pv
# sgd_trial_15_uv
# sgd_trial_30_uv
# sgd_trial_60_uv
# sgd_trial_120_uv
# sgd_pointbuy_15_pv
# sgd_pointbuy_30_pv
# sgd_pointbuy_60_pv
# sgd_pointbuy_120_pv
# sgd_pointbuy_15_uv
# sgd_pointbuy_30_uv
# sgd_pointbuy_60_uv
# sgd_pointbuy_120_uv
# sgd_endtrial_15_pv
# sgd_endtrial_30_pv
# sgd_endtrial_60_pv
# sgd_endtrial_120_pv
# sgd_endtrial_15_uv
# sgd_endtrial_30_uv
# sgd_endtrial_60_uv
# sgd_endtrial_120_uv
# zps_work_15_pv
# zps_work_30_pv
# zps_work_60_pv
# zps_work_120_pv
# zps_work_15_uv
# zps_work_30_uv
# zps_work_60_uv
# zps_work_120_uv
# zps_pointmod_15_pv
# zps_pointmod_30_pv
# zps_pointmod_60_pv
# zps_pointmod_120_pv
# zps_pointmod_15_uv
# zps_pointmod_30_uv
# zps_pointmod_60_uv
# zps_pointmod_120_uv
# zps_trial_15_pv
# zps_trial_30_pv
# zps_trial_60_pv
# zps_trial_120_pv
# zps_trial_15_uv
# zps_trial_30_uv
# zps_trial_60_uv
# zps_trial_120_uv
# zps_pointbuy_15_pv
# zps_pointbuy_30_pv
# zps_pointbuy_60_pv
# zps_pointbuy_120_pv
# zps_pointbuy_15_uv
# zps_pointbuy_30_uv
# zps_pointbuy_60_uv
# zps_pointbuy_120_uv
# zps_endtrial_15_pv
# zps_endtrial_30_pv
# zps_endtrial_60_pv
# zps_endtrial_120_pv
# zps_endtrial_15_uv
# zps_endtrial_30_uv
# zps_endtrial_60_uv
# zps_endtrial_120_uv
# lock_cnt_gtj
# jkzh_ab
# sgd_ab
# zps_ab
# jkzh_gjg

# %%
sum(train2['target']==1)/len(train2)
# Out:
# 0.10092895508956777

# %%
p1 = np.array([True]*100000 + [False]*162487)
p2 = np.array(list(train2['target']==1))
p3 = p1 | p2

# %%
train2 = train2.iloc[p3,:]
train2
# Out:
#         customer_wid  target  lastbuy_date_diff  thisyear_newsales  \
# 0           23233746       0           0.569168          -0.068518
# 3           23326992       0           0.524311           0.509116
# 5           23153460       0           0.831476           0.820612
# 7          152153637       0           0.524311           1.446653
# 8          176471075       0           0.310114           0.509116
# ...              ...     ...                ...                ...
# 485166      25900732       1          -0.918660          -0.633914
# 485193      23232083       1           0.831476           0.403935
# 485278      23426538       1           0.831476           1.446653
# 485301      23600051       1          -0.369129          -0.633914
# 485339      25677367       1           0.831476           0.820612
#
#         lastyear_newsales  thisyear_newbuycnt  lastyear_newbuycnt   cir_day  \
# 0               -0.410570            0.236641           -0.418181 -0.630646
# 3               -0.410570            0.236641           -0.418181 -0.630646
# 5                0.002712            1.282493           -0.060616  1.835276
# 7               -0.410570            1.282493           -0.418181  0.711380
# 8               -0.410570            1.282493           -0.418181  0.278429
# ...                   ...                 ...                 ...       ...
# 485166          -0.410570           -0.633914           -0.418181 -0.630646
# 485193          -0.410570            1.282493           -0.418181  0.278429
# 485278          -0.410570            1.282493           -0.418181  1.835276
# 485301           0.653506           -0.633914            1.050400  0.278429
# 485339           0.437992            1.282493           -0.060616  1.835276
#
#         register_count_pv_15_pv  register_count_pv_30_pv  ...  \
# 0                     -0.033373                -0.031403  ...
# 3                      1.001938                -0.031403  ...
# 5                     -0.033373                -0.031403  ...
# 7                     -0.033373                -0.031403  ...
# 8                     -0.033373                -0.031403  ...
# ...                         ...                      ...  ...
# 485166                -0.033373                -0.031403  ...
# 485193                -0.033373                -0.031403  ...
# 485278                -0.033373                -0.031403  ...
# 485301                -0.033373                -0.031403  ...
# 485339                -0.033373                -0.031403  ...
#
#         zps_endtrial_120_pv  zps_endtrial_15_uv  zps_endtrial_30_uv  \
# 0                 -0.005933           -0.002441           -0.002003
# 3                 -0.005933           -0.002441           -0.002003
# 5                 -0.005933           -0.002441           -0.002003
# 7                 -0.005933           -0.002441           -0.002003
# 8                 -0.005933           -0.002441           -0.002003
# ...                     ...                 ...                 ...
# 485166            -0.005933           -0.002441           -0.002003
# 485193            -0.005933           -0.002441           -0.002003
# 485278            -0.005933           -0.002441           -0.002003
# 485301            -0.005933           -0.002441           -0.002003
# 485339            -0.005933           -0.002441           -0.002003
#
#         zps_endtrial_60_uv  zps_endtrial_120_uv  lock_cnt_gtj       jkzh_ab  \
# 0                -0.002961            -0.005933      0.923418  8.890371e-09
# 3                -0.002961            -0.005933      0.923418  8.890371e-09
# 5                -0.002961            -0.005933     -0.232855  8.890371e-09
# 7                -0.002961            -0.005933      0.075394  8.890371e-09
# 8                -0.002961            -0.005933     -0.909402  8.890371e-09
# ...                    ...                  ...           ...           ...
# 485166           -0.002961            -0.005933     -0.907659  8.890371e-09
# 485193           -0.002961            -0.005933      0.158090  8.890371e-09
# 485278           -0.002961            -0.005933      0.923418  8.890371e-09
# 485301           -0.002961            -0.005933      0.923418  8.890371e-09
# 485339           -0.002961            -0.005933      0.923418  8.890371e-09
#
#           sgd_ab    zps_ab  jkzh_gjg
# 0      -0.375459  0.946822  0.961847
# 3      -0.375459 -0.377916 -0.374256
# 5      -0.375459 -0.377916 -0.374256
# 7       1.083090  0.203839 -0.374256
# 8      -0.375459 -0.377916 -0.374256
# ...          ...       ...       ...
# 485166 -0.375459 -0.328416 -0.374256
# 485193 -0.375459 -0.328416  0.079020
# 485278 -0.375459 -0.377916  0.961847
# 485301  1.083090  0.203839  0.961847
# 485339  1.083090  0.946822  0.961847
#
# [106679 rows x 360 columns]

# %%
train2.to_csv('721train.csv')

# %%
sum(test2['target']==1)/len(test2)
# Out:
# 0.05178806221200886

# %%
from time import time
import scipy.stats as stats

# %%
X_train=train2.drop(['target','customer_wid'],axis=1)
Y_train=train2['target']

# %%
#分类器使用 xgboost
clf1 = XGBClassifier()
 
#设定搜索的xgboost参数搜索范围，值搜索XGBoost的主要6个参数
param_dist = {
        'n_estimators':range(100,300,50),
        'max_depth':range(2,10,1),
        'learning_rate':np.linspace(0.01,0.1,10),
        'subsample':np.linspace(0.7,1.0,20),
        'colsample_bytree':np.linspace(0.5,0.98,10),
        'min_child_weight':range(1,5,1)
        }
 
#RandomizedSearchCV参数说明，clf1设置训练的学习器
#param_dist字典类型，放入参数搜索范围
#scoring = 'neg_log_loss'，精度评价方式设定为“neg_log_loss“
#n_iter=300，训练300次，数值越大，获得的参数精度越大，但是搜索时间越长
#n_jobs = -1，使用所有的CPU进行训练，默认为1，使用1个CPU
grid = RandomizedSearchCV(clf1,param_dist,cv = 3,scoring = 'roc_auc',n_iter=15,n_jobs = -1,verbose=2)

# %%
#在训练集上训练
grid.fit(X_train,Y_train)
#返回最优的训练器
best_estimator = grid.best_estimator_
print(best_estimator)
#输出最优训练器的精度
print(grid.best_score_)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1,
#               colsample_bytree=0.6066666666666667, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.06000000000000001,
#               max_bin=256, max_cat_to_onehot=4, max_delta_step=0, max_depth=8,
#               max_leaves=0, min_child_weight=2, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)
# 0.8401998460699122

# %%
#pca = PCA()  # 加载PCA算法，设置降维后主成分数目为2
#reduced_x = pca.fit_transform(x)

# %%
######保存
best_estimator.save_model("model_new.ubj")
# Out:
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.030000000000000006, max_depth=3, min_child_weight=3, n_estimators=150, subsample=0.7; total time= 1.4min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.09000000000000001, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.731578947368421; total time= 1.4min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.09000000000000001, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.731578947368421; total time= 1.4min
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.07, max_depth=2, min_child_weight=1, n_estimators=250, subsample=0.8894736842105263; total time= 1.7min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.05000000000000001, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8736842105263158; total time=  50.5s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.05000000000000001, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8736842105263158; total time=  59.3s
# [CV] END colsample_bytree=0.8733333333333333, learning_rate=0.06000000000000001, max_depth=2, min_child_weight=4, n_estimators=150, subsample=0.7947368421052632; total time= 1.2min
# [CV] END colsample_bytree=0.8733333333333333, learning_rate=0.06000000000000001, max_depth=2, min_child_weight=4, n_estimators=150, subsample=0.7947368421052632; total time= 1.2min
# [CV] END colsample_bytree=0.8733333333333333, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=250, subsample=0.731578947368421; total time= 7.2min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.06000000000000001, max_depth=8, min_child_weight=2, n_estimators=200, subsample=1.0; total time= 3.1min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.06000000000000001, max_depth=8, min_child_weight=2, n_estimators=200, subsample=1.0; total time= 3.1min
# [CV] END colsample_bytree=0.5, learning_rate=0.09000000000000001, max_depth=4, min_child_weight=4, n_estimators=250, subsample=0.9526315789473685; total time= 1.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.09000000000000001, max_depth=4, min_child_weight=4, n_estimators=250, subsample=0.9526315789473685; total time= 1.8min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.020000000000000004, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.731578947368421; total time= 1.2min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.020000000000000004, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.731578947368421; total time= 1.2min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.030000000000000006, max_depth=5, min_child_weight=2, n_estimators=250, subsample=0.8736842105263158; total time= 3.0min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.07, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7789473684210526; total time= 3.1min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.07, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7789473684210526; total time= 3.1min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=150, subsample=0.7157894736842105; total time= 1.7min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.030000000000000006, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8578947368421053; total time= 4.8min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.030000000000000006, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8578947368421053; total time= 4.8min
# [CV] END colsample_bytree=0.98, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=250, subsample=0.7473684210526316; total time= 3.5min
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.07, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7157894736842105; total time= 2.3min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.030000000000000006, max_depth=3, min_child_weight=3, n_estimators=150, subsample=0.7; total time= 1.3min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.030000000000000006, max_depth=3, min_child_weight=3, n_estimators=150, subsample=0.7; total time= 1.3min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.09000000000000001, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.731578947368421; total time= 1.3min
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.07, max_depth=2, min_child_weight=1, n_estimators=250, subsample=0.8894736842105263; total time= 1.6min
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.07, max_depth=2, min_child_weight=1, n_estimators=250, subsample=0.8894736842105263; total time= 1.6min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.05000000000000001, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8736842105263158; total time=  49.6s
# [CV] END colsample_bytree=0.8733333333333333, learning_rate=0.06000000000000001, max_depth=2, min_child_weight=4, n_estimators=150, subsample=0.7947368421052632; total time=  59.8s
# [CV] END colsample_bytree=0.8733333333333333, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=250, subsample=0.731578947368421; total time= 7.0min
# [CV] END colsample_bytree=0.8733333333333333, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=250, subsample=0.731578947368421; total time= 7.0min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.06000000000000001, max_depth=8, min_child_weight=2, n_estimators=200, subsample=1.0; total time= 3.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.09000000000000001, max_depth=4, min_child_weight=4, n_estimators=250, subsample=0.9526315789473685; total time= 1.7min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.020000000000000004, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.731578947368421; total time= 1.1min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.030000000000000006, max_depth=5, min_child_weight=2, n_estimators=250, subsample=0.8736842105263158; total time= 2.9min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.030000000000000006, max_depth=5, min_child_weight=2, n_estimators=250, subsample=0.8736842105263158; total time= 2.9min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.07, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7789473684210526; total time= 3.0min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=150, subsample=0.7157894736842105; total time= 1.7min
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=150, subsample=0.7157894736842105; total time= 1.7min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.030000000000000006, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8578947368421053; total time= 4.6min
# [CV] END colsample_bytree=0.98, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=250, subsample=0.7473684210526316; total time= 3.3min
# [CV] END colsample_bytree=0.98, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=250, subsample=0.7473684210526316; total time= 3.4min
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.07, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7157894736842105; total time= 2.3min
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.07, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7157894736842105; total time= 2.2min

# %%
dt_train = df[(df['class']=="test")&(df['date_wid']>='2023-04-01')&(df['date_wid']<'2023-05-01')]

# %%
dt_train=dt_train.drop(['account_code','social_credit_num','created','date_wid','class'], axis=1)
dt_train['lastbuy_date_diff'] = dt_train['lastbuy_date_diff'].fillna(9999)
dt_train = dt_train.fillna(0)
dt_train[['unit_level','act_category','act_alias','ent_level','ent_category']]=dt_train[['unit_level','act_category','act_alias','ent_level','ent_category']].astype(str)

# %%
dt_train2 = dt_train.copy()
a = dt_train2
i=0
for column in list(dt_train2.columns[2:]):
    a[column]=fp.woe_trans(dt_train2[column], civ_list[i])
    i += 1

# %%
dt_train2
# Out:
#         customer_wid  target  lastbuy_date_diff  thisyear_newsales  \
# 2           23185208       0           0.569168           0.403935
# 10          39065407       0          -0.369129          -0.633914
# 14          23476399       0          -0.369129          -0.633914
# 16         538795683       0           0.831476          -0.068518
# 19          23199395       1           1.065428           1.446653
# ...              ...     ...                ...                ...
# 485321      27097726       0          -0.918660          -0.633914
# 485323      23398521       0          -0.918660          -0.633914
# 485333      23521111       0           0.310114           0.403935
# 485340      38655317       0          -0.369129          -0.633914
# 485345     104255017       0          -0.918660          -0.633914
#
#         lastyear_newsales  thisyear_newbuycnt  lastyear_newbuycnt   cir_day  \
# 2               -0.410570            0.236641           -0.418181 -0.630646
# 10               0.002712           -0.633914           -0.060616 -0.630646
# 14               0.437992           -0.633914           -0.060616 -0.630646
# 16               0.002712            0.236641           -0.060616  0.278429
# 19              -0.410570            1.282493           -0.418181  0.711380
# ...                   ...                 ...                 ...       ...
# 485321          -0.410570           -0.633914           -0.418181 -0.630646
# 485323          -0.410570           -0.633914           -0.418181 -0.630646
# 485333           0.653506            0.236641            1.050400  0.711380
# 485340           0.437992           -0.633914            1.050400  0.278429
# 485345          -0.410570           -0.633914           -0.418181 -0.630646
#
#         register_count_pv_15_pv  register_count_pv_30_pv  ...  \
# 2                     -0.033373                -0.031403  ...
# 10                    -0.033373                -0.031403  ...
# 14                    -0.033373                -0.031403  ...
# 16                    -0.033373                -0.031403  ...
# 19                    -0.033373                -0.031403  ...
# ...                         ...                      ...  ...
# 485321                -0.033373                -0.031403  ...
# 485323                -0.033373                -0.031403  ...
# 485333                -0.033373                -0.031403  ...
# 485340                -0.033373                -0.031403  ...
# 485345                -0.033373                -0.031403  ...
#
#         zps_endtrial_120_pv  zps_endtrial_15_uv  zps_endtrial_30_uv  \
# 2                 -0.005933           -0.002441           -0.002003
# 10                -0.005933           -0.002441           -0.002003
# 14                -0.005933           -0.002441           -0.002003
# 16                -0.005933           -0.002441           -0.002003
# 19                -0.005933           -0.002441           -0.002003
# ...                     ...                 ...                 ...
# 485321            -0.005933           -0.002441           -0.002003
# 485323            -0.005933           -0.002441           -0.002003
# 485333            -0.005933           -0.002441           -0.002003
# 485340            -0.005933           -0.002441           -0.002003
# 485345            -0.005933           -0.002441           -0.002003
#
#         zps_endtrial_60_uv  zps_endtrial_120_uv  lock_cnt_gtj       jkzh_ab  \
# 2                -0.002961            -0.005933     -0.232855  8.890371e-09
# 10               -0.002961            -0.005933     -0.232855  8.890371e-09
# 14               -0.002961            -0.005933      0.158090  8.890371e-09
# 16               -0.002961            -0.005933     -0.232855  8.890371e-09
# 19               -0.002961            -0.005933     -0.907659  8.890371e-09
# ...                    ...                  ...           ...           ...
# 485321           -0.002961            -0.005933     -0.909402  8.890371e-09
# 485323           -0.002961            -0.005933     -0.907659  8.890371e-09
# 485333           -0.002961            -0.005933      0.923418  8.890371e-09
# 485340           -0.002961            -0.005933     -0.232855  8.890371e-09
# 485345           -0.002961            -0.005933     -0.907659  8.890371e-09
#
#           sgd_ab    zps_ab  jkzh_gjg
# 2      -0.375459 -0.377916  0.079020
# 10     -0.375459 -0.328416  0.079020
# 14      1.083090  0.946822 -0.374256
# 16     -0.375459 -0.377916 -0.374256
# 19     -0.375459 -0.377916 -0.374256
# ...          ...       ...       ...
# 485321 -0.375459 -0.377916 -0.374256
# 485323 -0.375459 -0.328416  0.079020
# 485333  1.083090  0.946822 -0.374256
# 485340  0.289701  0.203839 -0.374256
# 485345 -0.375459 -0.377916 -0.374256
#
# [85443 rows x 360 columns]

# %%
p1 = np.array([True]*32551 + [False]*52892)
p2 = np.array(list(dt_train2['target']==1))
p3 = p1 | p2
dt_train2 = dt_train2.iloc[p3,:]

# %%
sum(dt_train2['target']==1)/len(dt_train2)
# Out:
# 0.12386800996151234

# %%
dt_train2.to_csv('721dt.csv')

# %%
X_dt=dt_train2.drop(['target','customer_wid'],axis=1)
Y_dt=dt_train2['target']
Y_dt_pred = best_estimator.predict_proba(X_dt)
Y_dt_pred_1 = Y_dt_pred[:,1]

# %%
###最佳阈值
def Find_Optimal_Cutoff(TPR, FPR, threshold):
    y = TPR - FPR
    Youden_index = np.argmax(y)  # Only the first occurrence is returned.
    optimal_threshold = threshold[Youden_index]
    point = [FPR[Youden_index], TPR[Youden_index]]
    return optimal_threshold, point

###ROC
fpr, tpr, thersholds = roc_curve(Y_dt, Y_dt_pred_1, pos_label=1)
best_thershold, point = Find_Optimal_Cutoff(tpr, fpr, thersholds)
roc_auc = auc(fpr, tpr)
 
plt.plot(fpr, tpr, 'k--', label='ROC (area = {0:.2f})'.format(roc_auc), lw=2)
 
plt.xlim([-0.05, 1.05])  # 设置x、y轴的上下限，以免和边缘重合，更好的观察图像的整体
plt.ylim([-0.05, 1.05])
plt.plot(point[0], point[1], marker='o', color='r')
plt.text(point[0], point[1], f'Threshold:{best_thershold:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')  # 可以使用中文，但需要导入一些库即字体
plt.title('ROC Curve')
plt.legend(loc="lower right")

# %%
roc_auc
# Out:
# 0.8198543235338568

# %%
xgb.plot_importance(best_estimator,max_num_features=20,importance_type='gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
###Cir day
hist(test2['cir_day'],cumulative=True,histtype='step',density=True)
hist(train2['cir_day'],cumulative=True,histtype='step',density=True,label = "7.18")
# Out:
# (array([0.7135425 , 0.7135425 , 0.7135425 , 0.86803401, 0.86803401,
#         0.92885198, 0.92885198, 0.92885198, 0.92885198, 1.        ]),
#  array([-0.63064592, -0.38405371, -0.13746149,  0.10913072,  0.35572293,
#          0.60231515,  0.84890736,  1.09549958,  1.34209179,  1.588684  ,
#          1.83527622]),
#  [<matplotlib.patches.Polygon at 0x7fca3adcde10>])

# %%
test = df[(df['class']=="test")&(df['date_wid']=='2023-07-18')]

# %%
test=test.drop(['account_code','social_credit_num','created','date_wid','class'], axis=1)
test['lastbuy_date_diff'] = test['lastbuy_date_diff'].fillna(9999)
test = test.fillna(0)

# %%
test[['unit_level','act_category','act_alias','ent_level','ent_category']]=test[['unit_level','act_category','act_alias','ent_level','ent_category']].astype(str)

# %%
test2 = test.copy()

# %%
a = test2
i=0
for column in list(test2.columns[2:]):
    a[column]=fp.woe_trans(test2[column], civ_list[i])
    i += 1

# %%
test2.to_csv('721test.csv')

# %%
p1 = np.array([True]*15000 + [False]*69421)
p2 = np.array(list(test2['target']==1))

# %%
p3 = p1 | p2

# %%
test2 = test2.iloc[p3,:]

# %%
sum(test2['target'])/15000
# Out:
# 0.29146666666666665

# %%
X_test=test2.drop(['target','customer_wid'],axis=1)
Y_test=test2['target']

# %%
Y_test_pred = best_estimator.predict_proba(X_test)

# %%
Y_test_pred_1 = Y_test_pred[:,1]

# %%
###最佳阈值
def Find_Optimal_Cutoff(TPR, FPR, threshold):
    y = TPR - FPR
    Youden_index = np.argmax(y)  # Only the first occurrence is returned.
    optimal_threshold = threshold[Youden_index]
    point = [FPR[Youden_index], TPR[Youden_index]]
    return optimal_threshold, point

###ROC
fpr, tpr, thersholds = roc_curve(Y_test, Y_test_pred_1, pos_label=1)
best_thershold, point = Find_Optimal_Cutoff(tpr, fpr, thersholds)
roc_auc = auc(fpr, tpr)
 
plt.plot(fpr, tpr, 'k--', label='ROC (area = {0:.2f})'.format(roc_auc), lw=2)
 
plt.xlim([-0.05, 1.05])  # 设置x、y轴的上下限，以免和边缘重合，更好的观察图像的整体
plt.ylim([-0.05, 1.05])
plt.plot(point[0], point[1], marker='o', color='r')
plt.text(point[0], point[1], f'Threshold:{best_thershold:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')  # 可以使用中文，但需要导入一些库即字体
plt.title('ROC Curve')
plt.legend(loc="lower right")

# %%
roc_auc
# Out:
# 0.5510478410232366

# %%
xgb.plot_importance(best_estimator,max_num_features=20,importance_type='gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
weight = pd.Series(best_estimator.get_booster().get_score(importance_type='gain')).sort_values(ascending=False).head(20)
weight
# Out:
# renew_lock_cnt                 118.350021
# min_renew_date_diff             21.598600
# act_alias                       15.480365
# lastbuy_date_diff               14.785036
# ent_level                       12.616471
# act_category                     9.369637
# zps_pointbuy_60_uv               9.011218
# explicit_demand_flag_120_pv      7.940004
# gjg_start_15_uv                  7.480453
# jkzh_endtrial_60_uv              7.360945
# register_count_60_uv             7.253515
# sgd_jc_15_uv                     7.142254
# thisyear_newbuycnt               7.037286
# zps_endtrial_15_pv               6.991401
# sgd_pointbuy_60_uv               6.900464
# explicit_demand_flag_120_uv      6.862906
# signup_count_60_uv               6.598028
# branch                           6.475869
# vod_time_60_uv                   6.120877
# share_count_pv_120_pv            6.085343
# dtype: float64
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.7; total time=  23.9s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.7; total time=  23.5s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.020000000000000004, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.763157894736842; total time= 1.1min
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=100, subsample=0.9842105263157894; total time=   7.2s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=100, subsample=0.9842105263157894; total time=   7.5s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.1, max_depth=2, min_child_weight=4, n_estimators=100, subsample=0.9842105263157894; total time=   7.2s
# [CV] END colsample_bytree=0.82, learning_rate=0.07, max_depth=5, min_child_weight=7, n_estimators=250, subsample=0.8105263157894737; total time=  47.6s
# [CV] END colsample_bytree=0.82, learning_rate=0.07, max_depth=5, min_child_weight=7, n_estimators=250, subsample=0.8105263157894737; total time=  47.7s
# [CV] END colsample_bytree=0.5533333333333333, learning_rate=0.04000000000000001, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.763157894736842; total time=  14.5s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.01, max_depth=8, min_child_weight=8, n_estimators=250, subsample=0.7947368421052632; total time= 1.2min
# [CV] END colsample_bytree=0.82, learning_rate=0.030000000000000006, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.9210526315789473; total time=  41.8s
# [CV] END colsample_bytree=0.82, learning_rate=0.030000000000000006, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.9210526315789473; total time=  41.9s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.04000000000000001, max_depth=5, min_child_weight=3, n_estimators=150, subsample=0.8736842105263158; total time=  24.3s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.04000000000000001, max_depth=5, min_child_weight=3, n_estimators=150, subsample=0.8736842105263158; total time=  24.5s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.06000000000000001, max_depth=3, min_child_weight=6, n_estimators=150, subsample=0.8421052631578947; total time=  16.2s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.06000000000000001, max_depth=3, min_child_weight=6, n_estimators=150, subsample=0.8421052631578947; total time=  16.2s
# [CV] END colsample_bytree=0.98, learning_rate=0.030000000000000006, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8105263157894737; total time=  13.9s
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.1, max_depth=7, min_child_weight=8, n_estimators=100, subsample=0.8736842105263158; total time=  19.6s
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.1, max_depth=7, min_child_weight=8, n_estimators=100, subsample=0.8736842105263158; total time=  20.0s
# [CV] END colsample_bytree=0.82, learning_rate=0.05000000000000001, max_depth=3, min_child_weight=1, n_estimators=250, subsample=0.7157894736842105; total time=  31.0s
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.09000000000000001, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.7789473684210526; total time=  13.5s
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.09000000000000001, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.7789473684210526; total time=  13.6s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.06000000000000001, max_depth=3, min_child_weight=6, n_estimators=150, subsample=0.9842105263157894; total time=  15.1s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.06000000000000001, max_depth=3, min_child_weight=6, n_estimators=150, subsample=0.9842105263157894; total time=  15.6s
# [CV] END colsample_bytree=0.5533333333333333, learning_rate=0.030000000000000006, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.763157894736842; total time=  21.0s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.7; total time=  24.2s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.020000000000000004, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.763157894736842; total time= 1.2min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.020000000000000004, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.763157894736842; total time= 1.1min
# [CV] END colsample_bytree=0.82, learning_rate=0.07, max_depth=5, min_child_weight=7, n_estimators=250, subsample=0.8105263157894737; total time=  48.7s
# [CV] END colsample_bytree=0.5533333333333333, learning_rate=0.04000000000000001, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.763157894736842; total time=  14.6s
# [CV] END colsample_bytree=0.5533333333333333, learning_rate=0.04000000000000001, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.763157894736842; total time=  14.5s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.01, max_depth=8, min_child_weight=8, n_estimators=250, subsample=0.7947368421052632; total time= 1.2min
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.01, max_depth=8, min_child_weight=8, n_estimators=250, subsample=0.7947368421052632; total time= 1.2min
# [CV] END colsample_bytree=0.82, learning_rate=0.030000000000000006, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.9210526315789473; total time=  43.3s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.04000000000000001, max_depth=5, min_child_weight=3, n_estimators=150, subsample=0.8736842105263158; total time=  25.1s
# [CV] END colsample_bytree=0.7133333333333334, learning_rate=0.06000000000000001, max_depth=3, min_child_weight=6, n_estimators=150, subsample=0.8421052631578947; total time=  16.4s
# [CV] END colsample_bytree=0.98, learning_rate=0.030000000000000006, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8105263157894737; total time=  14.8s
# [CV] END colsample_bytree=0.98, learning_rate=0.030000000000000006, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8105263157894737; total time=  14.4s
# [CV] END colsample_bytree=0.6066666666666667, learning_rate=0.1, max_depth=7, min_child_weight=8, n_estimators=100, subsample=0.8736842105263158; total time=  20.1s
# [CV] END colsample_bytree=0.82, learning_rate=0.05000000000000001, max_depth=3, min_child_weight=1, n_estimators=250, subsample=0.7157894736842105; total time=  31.9s
# [CV] END colsample_bytree=0.82, learning_rate=0.05000000000000001, max_depth=3, min_child_weight=1, n_estimators=250, subsample=0.7157894736842105; total time=  31.7s
# [CV] END colsample_bytree=0.9266666666666666, learning_rate=0.09000000000000001, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.7789473684210526; total time=  14.0s
# [CV] END colsample_bytree=0.7666666666666666, learning_rate=0.06000000000000001, max_depth=3, min_child_weight=6, n_estimators=150, subsample=0.9842105263157894; total time=  15.4s
# [CV] END colsample_bytree=0.5533333333333333, learning_rate=0.030000000000000006, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.763157894736842; total time=  21.3s
# [CV] END colsample_bytree=0.5533333333333333, learning_rate=0.030000000000000006, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.763157894736842; total time=  21.4s

# %%
#########
#####样本分布程度
from scipy.stats import ks_2samp
ks_2samp(train2.iloc[:,1],test2.iloc[:,1]).pvalue
# Out:
# 5.790906765735834e-40

# %%
plt.hist(train2.iloc[:,2],bins=10)
plt.title("data analyze")
plt.xlabel("height")
plt.ylabel("rate")
 
plt.show()

# %%
plt.hist(test2.iloc[:,2],bins=10)
plt.title("data analyze")
plt.xlabel("height")
plt.ylabel("rate")
 
plt.show()

# %%
base_data=spark.read.option("header","true").csv("/tmp/base_ad20230721.csv").toPandas()
# Out:
# 23/07/24 01:28:10 ERROR net.ScriptBasedMapping: Script /usr/hdp/3.1.4.0-315/hadoop/conf/topology_script.py returned 1 values when 3 were expected.
# 23/07/24 01:28:12 WARN util.package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 23/07/24 01:28:12 ERROR net.ScriptBasedMapping: Script /usr/hdp/3.1.4.0-315/hadoop/conf/topology_script.py returned 1 values when 23 were expected.
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py", line 1207, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py", line 1033, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py", line 1212, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server (127.0.0.1:45478)
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py", line 977, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py", line 1115, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in _get_connection(self)
#     976         try:
# --> 977             connection = self.deque.pop()
#     978         except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in start(self)
#    1114         try:
# -> 1115             self.socket.connect((self.address, self.port))
#    1116             self.stream = self.socket.makefile("rb")
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# /tmp/ipykernel_1471/2828627314.py in <module>
# ----> 1 base_data=spark.read.option("header","true").csv("/tmp/base_ad20230721.csv").toPandas()
#
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py in toPandas(self)
#     139
#     140         # Below is toPandas without Arrow optimization.
# --> 141         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#     142         column_counter = Counter(self.columns)
#     143
#
# /usr/local/spark/python/pyspark/sql/dataframe.py in columns(self)
#    1197         ['age', 'name']
#    1198         """
# -> 1199         return [f.name for f in self.schema.fields]
#    1200
#    1201     def colRegex(self, colName):
#
# /usr/local/spark/python/pyspark/sql/dataframe.py in schema(self)
#     274         if self._schema is None:
#     275             try:
# --> 276                 self._schema = _parse_datatype_json_string(self._jdf.schema().json())
#     277             except AttributeError as e:
#     278                 raise Exception(
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1029          if `binary` is `True`.
#    1030         """
# -> 1031         connection = self._get_connection()
#    1032         try:
#    1033             response = connection.send_command(command)
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in _get_connection(self)
#     977             connection = self.deque.pop()
#     978         except IndexError:
# --> 979             connection = self._create_connection()
#     980         return connection
#     981
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in _create_connection(self)
#     983         connection = GatewayConnection(
#     984             self.gateway_parameters, self.gateway_property)
# --> 985         connection.start()
#     986         return connection
#     987
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in start(self)
#    1125                 "server ({0}:{1})".format(self.address, self.port)
#    1126             logger.exception(msg)
# -> 1127             raise Py4JNetworkError(msg, e)
#    1128
#    1129     def _authenticate_connection(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:45478)

# %%
import sys
sys.path.append('/data/gtair/tools/DWH')
from GlodonSparkSession3 import GlodonSparkSession
import os

# %%
spark = GlodonSparkSession().getSparkSession(log_lev='ERROR',resource_lev='high')
# Out:
# ===============>app_name: gaokx_high_620502111
# =====================>resource_lev: high
# Warning: Ignoring non-Spark config property: yarn.executor.num
# Warning: Ignoring non-Spark config property: yarn.executor.cores
# 23/07/24 01:27:32 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/07/24 01:27:33 WARN util.Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/07/24 01:27:34 WARN shortcircuit.DomainSocketFactory: The short-circuit local reads feature cannot be used because libhadoop cannot be loaded.
# 23/07/24 01:27:34 WARN yarn.Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 23/07/24 01:27:46 WARN spark.ExecutorAllocationManager: Dynamic allocation without a shuffle service is an experimental feature.
# 23/07/24 01:27:46 WARN cluster.YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!

# %%
# ?best_estimator
# Out:
# Type:        XGBClassifier
# String form:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#            colsample_bylevel=1 <...> _parallel_tree=1, predictor='auto', random_state=0,
#            reg_alpha=0, reg_lambda=1, ...)
# File:        /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py
# Docstring:
# Implementation of the scikit-learn API for XGBoost classification.
#
#
# Parameters
# ----------
#
#     n_estimators : int
#         Number of boosting rounds.
#
#     max_depth :  Optional[int]
#         Maximum tree depth for base learners.
#     max_leaves :
#         Maximum number of leaves; 0 indicates no limit.
#     max_bin :
#         If using histogram-based algorithm, maximum number of bins per feature
#     grow_policy :
#         Tree growing policy. 0: favor splitting at nodes closest to the node, i.e. grow
#         depth-wise. 1: favor splitting at nodes with highest loss change.
#     learning_rate : Optional[float]
#         Boosting learning rate (xgb's "eta")
#     verbosity : Optional[int]
#         The degree of verbosity. Valid values are 0 (silent) - 3 (debug).
#     objective : typing.Union[str, typing.Callable[[numpy.ndarray, numpy.ndarray], typing.Tuple[numpy.ndarray, numpy.ndarray]], NoneType]
#         Specify the learning task and the corresponding learning objective or
#         a custom objective function to be used (see note below).
#     booster: Optional[str]
#         Specify which booster to use: gbtree, gblinear or dart.
#     tree_method: Optional[str]
#         Specify which tree method to use.  Default to auto.  If this parameter is set to
#         default, XGBoost will choose the most conservative option available.  It's
#         recommended to study this option from the parameters document :doc:`tree method
#         </treemethod>`
#     n_jobs : Optional[int]
#         Number of parallel threads used to run xgboost.  When used with other Scikit-Learn
#         algorithms like grid search, you may choose which algorithm to parallelize and
#         balance the threads.  Creating thread contention will significantly slow down both
#         algorithms.
#     gamma : Optional[float]
#         (min_split_loss) Minimum loss reduction required to make a further partition on a
#         leaf node of the tree.
#     min_child_weight : Optional[float]
#         Minimum sum of instance weight(hessian) needed in a child.
#     max_delta_step : Optional[float]
#         Maximum delta step we allow each tree's weight estimation to be.
#     subsample : Optional[float]
#         Subsample ratio of the training instance.
#     sampling_method :
#         Sampling method. Used only by `gpu_hist` tree method.
#           - `uniform`: select random training instances uniformly.
#           - `gradient_based` select random training instances with higher probability when
#             the gradient and hessian are larger. (cf. CatBoost)
#     colsample_bytree : Optional[float]
#         Subsample ratio of columns when constructing each tree.
#     colsample_bylevel : Optional[float]
#         Subsample ratio of columns for each level.
#     colsample_bynode : Optional[float]
#         Subsample ratio of columns for each split.
#     reg_alpha : Optional[float]
#         L1 regularization term on weights (xgb's alpha).
#     reg_lambda : Optional[float]
#         L2 regularization term on weights (xgb's lambda).
#     scale_pos_weight : Optional[float]
#         Balancing of positive and negative weights.
#     base_score : Optional[float]
#         The initial prediction score of all instances, global bias.
#     random_state : Optional[Union[numpy.random.RandomState, int]]
#         Random number seed.
#
#         .. note::
#
#            Using gblinear booster with shotgun updater is nondeterministic as
#            it uses Hogwild algorithm.
#
#     missing : float, default np.nan
#         Value in the data which needs to be present as a missing value.
#     num_parallel_tree: Optional[int]
#         Used for boosting random forest.
#     monotone_constraints : Optional[Union[Dict[str, int], str]]
#         Constraint of variable monotonicity.  See :doc:`tutorial </tutorials/monotonic>`
#         for more information.
#     interaction_constraints : Optional[Union[str, List[Tuple[str]]]]
#         Constraints for interaction representing permitted interactions.  The
#         constraints must be specified in the form of a nested list, e.g. ``[[0, 1], [2,
#         3, 4]]``, where each inner list is a group of indices of features that are
#         allowed to interact with each other.  See :doc:`tutorial
#         </tutorials/feature_interaction_constraint>` for more information
#     importance_type: Optional[str]
#         The feature importance type for the feature_importances\_ property:
#
#         * For tree model, it's either "gain", "weight", "cover", "total_gain" or
#           "total_cover".
#         * For linear model, only "weight" is defined and it's the normalized coefficients
#           without bias.
#
#     gpu_id : Optional[int]
#         Device ordinal.
#     validate_parameters : Optional[bool]
#         Give warnings for unknown parameter.
#     predictor : Optional[str]
#         Force XGBoost to use specific predictor, available choices are [cpu_predictor,
#         gpu_predictor].
#     enable_categorical : bool
#
#         .. versionadded:: 1.5.0
#
#         .. note:: This parameter is experimental
#
#         Experimental support for categorical data.  When enabled, cudf/pandas.DataFrame
#         should be used to specify categorical data type.  Also, JSON/UBJSON
#         serialization format is required.
#
#     max_cat_to_onehot : Optional[int]
#
#         .. versionadded:: 1.6.0
#
#         .. note:: This parameter is experimental
#
#         A threshold for deciding whether XGBoost should use one-hot encoding based split
#         for categorical data.  When number of categories is lesser than the threshold
#         then one-hot encoding is chosen, otherwise the categories will be partitioned
#         into children nodes.  Only relevant for regression and binary classification.
#         See :doc:`Categorical Data </tutorials/categorical>` for details.
#
#     eval_metric : Optional[Union[str, List[str], Callable]]
#
#         .. versionadded:: 1.6.0
#
#         Metric used for monitoring the training result and early stopping.  It can be a
#         string or list of strings as names of predefined metric in XGBoost (See
#         doc/parameter.rst), one of the metrics in :py:mod:`sklearn.metrics`, or any other
#         user defined metric that looks like `sklearn.metrics`.
#
#         If custom objective is also provided, then custom metric should implement the
#         corresponding reverse link function.
#
#         Unlike the `scoring` parameter commonly used in scikit-learn, when a callable
#         object is provided, it's assumed to be a cost function and by default XGBoost will
#         minimize the result during early stopping.
#
#         For advanced usage on Early stopping like directly choosing to maximize instead of
#         minimize, see :py:obj:`xgboost.callback.EarlyStopping`.
#
#         See :doc:`Custom Objective and Evaluation Metric </tutorials/custom_metric_obj>`
#         for more.
#
#         .. note::
#
#              This parameter replaces `eval_metric` in :py:meth:`fit` method.  The old one
#              receives un-transformed prediction regardless of whether custom objective is
#              being used.
#
#         .. code-block:: python
#
#             from sklearn.datasets import load_diabetes
#             from sklearn.metrics import mean_absolute_error
#             X, y = load_diabetes(return_X_y=True)
#             reg = xgb.XGBRegressor(
#                 tree_method="hist",
#                 eval_metric=mean_absolute_error,
#             )
#             reg.fit(X, y, eval_set=[(X, y)])
#
#     early_stopping_rounds : Optional[int]
#
#         .. versionadded:: 1.6.0
#
#         Activates early stopping. Validation metric needs to improve at least once in
#         every **early_stopping_rounds** round(s) to continue training.  Requires at least
#         one item in **eval_set** in :py:meth:`fit`.
#
#         The method returns the model from the last iteration (not the best one).  If
#         there's more than one item in **eval_set**, the last entry will be used for early
#         stopping.  If there's more than one metric in **eval_metric**, the last metric
#         will be used for early stopping.
#
#         If early stopping occurs, the model will have three additional fields:
#         :py:attr:`best_score`, :py:attr:`best_iteration` and
#         :py:attr:`best_ntree_limit`.
#
#         .. note::
#
#             This parameter replaces `early_stopping_rounds` in :py:meth:`fit` method.
#
#     callbacks : Optional[List[TrainingCallback]]
#         List of callback functions that are applied at end of each iteration.
#         It is possible to use predefined callbacks by using
#         :ref:`Callback API <callback_api>`.
#
#         .. note::
#
#            States in callback are not preserved during training, which means callback
#            objects can not be reused for multiple training sessions without
#            reinitialization or deepcopy.
#
#         .. code-block:: python
#
#             for params in parameters_grid:
#                 # be sure to (re)initialize the callbacks before each run
#                 callbacks = [xgb.callback.LearningRateScheduler(custom_rates)]
#                 xgboost.train(params, Xy, callbacks=callbacks)
#
#     kwargs : dict, optional
#         Keyword arguments for XGBoost Booster object.  Full documentation of parameters
#         can be found :doc:`here </parameter>`.
#         Attempting to set a parameter via the constructor args and \*\*kwargs
#         dict simultaneously will result in a TypeError.
#
#         .. note:: \*\*kwargs unsupported by scikit-learn
#
#             \*\*kwargs is unsupported by scikit-learn.  We do not guarantee
#             that parameters passed via this argument will interact properly
#             with scikit-learn.
#
#         .. note::  Custom objective function
#
#             A custom objective function can be provided for the ``objective``
#             parameter. In this case, it should have the signature
#             ``objective(y_true, y_pred) -> grad, hess``:
#
#             y_true: array_like of shape [n_samples]
#                 The target values
#             y_pred: array_like of shape [n_samples]
#                 The predicted values
#
#             grad: array_like of shape [n_samples]
#                 The value of the gradient for each sample point.
#             hess: array_like of shape [n_samples]
#                 The value of the second derivative for each sample point
